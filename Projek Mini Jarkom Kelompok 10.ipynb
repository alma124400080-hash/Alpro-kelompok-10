# %% [markdown]
# # PRJOEK MINI ALPRO

# %% [markdown]
# Anggota Kelompok:
# 1. Alma Riski Mardansyah (124400080)
# 2. Lusiana Maheswari (124400092)
# 3. M. Tegar Herawan Wijaya (124400070)

# %%
mahasiswa = []  

def tambah_mahasiswa():
    print("\n=== Tambah Data Mahasiswa ===")
    input("Nama        : ")
    input("NIM         : ")
    input("Tempat/Tgl Lahir : ")
    input("Alamat      : ")

    data = {
        "nama": nama,
        "nim": nim,
        "ttl": ttl,
        "alamat": alamat
    }
    mahasiswa.append(data)
    print("Data berhasil ditambahkan!\n")


def tampilkan_data():
    print("\n=== Data Mahasiswa ===")
    if len(mahasiswa) == 0:
        print("Belum ada data.\n")
        return
    
    for i, mhs in enumerate(mahasiswa, start=1):
        print(f"{i}. Nama: {mhs['nama']}")
        print(f"   NIM : {mhs['nim']}")
        print(f"   TTL : {mhs['ttl']}")
        print(f"   Alamat : {mhs['alamat']}\n")


def menu():
    while True:
        print("===== MENU DATA MAHASISWA =====")
        print("1. Tambah Data")
        print("2. Tampilkan Data")
        print("3. Keluar")
        
        pilihan = input("Pilih menu: ")
        
        if pilihan == "1":
            tambah_mahasiswa()
        elif pilihan == "2":
            tampilkan_data()
        elif pilihan == "3":
            print("Program selesai.")
            break
        else:
            print("Pilihan tidak valid!\n")

menu()
# Out:
# ===== MENU DATA MAHASISWA =====
# 1. Tambah Data
# 2. Tampilkan Data
# 3. Keluar

# %% [markdown]
# # Penjelasan
#
# Fungsi (def)
# Digunakan untuk memisahkan bagian kode supaya lebih rapi dan mudah dipakai lagi.
#
# Perulangan (Loop)
# Digunakan ketika menampilkan seluruh data mahasiswa.
#
# Struktur Menu (Percabangan IF-ELSE)
# Ini memastikan program melakukan aksi sesuai nomor menu.
#
# Input
# untuk menginput data pengguna
#
# Dictionary
# Digunakan untuk menyimpan data 1 mahasiswa dalam bentuk pasangan key : value.
#
# List
# Digunakan untuk menyimpan banyak data mahasiswa.
